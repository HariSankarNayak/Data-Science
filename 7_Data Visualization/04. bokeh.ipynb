# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d99db76f-de67-4ab7-898f-71edc96b3dd7">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.sampledata.iris import flowers

output_notebook()

p = figure(
    title="Iris Dataset",
    width=700,
    height=400
)

p.scatter(
    flowers['petal_length'],
    flowers['petal_width'],
    marker="circle",
    size=10,
    color="navy",
    alpha=0.5
)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e71590b7-f6a2-4630-afcf-5b3051e10b1f">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# Cell In[9], line 22
#       7 p = figure(
#       8     title="Iris Dataset",
#       9     width=700,
#      10     height=400
#      11 )
#      13 p.scatter(
#      14     flowers['petal_length'],
#      15     flowers['petal_width'],
#    (...)
#      19     alpha=0.5
#      20 )
# ---> 22 show(p)
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\io\showing.py:167, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     164 state = curstate()
#     166 if isinstance(obj, UIElement) or isinstance(obj, DOMNode) or isinstance(obj, Sequence):
# --> 167     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     169 def is_application(obj: Any) -> TypeGuard[Application]:
#     170     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\io\showing.py:215, in _show_with_state(obj, state, browser, new, notebook_handle)
#     213 if state.notebook:
#     214     assert state.notebook_type is not None
# --> 215     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     216     shown = True
#     218 if state.file or not shown:
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\io\notebook.py:372, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     370 if _HOOKS[notebook_type][action] is None:
#     371     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 372 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\io\notebook.py:605, in show_doc(obj, state, notebook_handle)
#     601 '''
#     602
#     603 '''
#     604 if obj not in state.document.roots:
# --> 605     state.document.add_root(obj)
#     607 from ..embed.notebook import notebook_content
#     608 comms_target = make_id() if notebook_handle else None
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\document\document.py:338, in Document.add_root(self, model, setter)
#     335 if model in self._roots:
#     336     return
# --> 338 with self.models.freeze():
#     339     self._roots.append(model)
#     341 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\document\models.py:215, in DocumentModelManager.recompute(self)
#     213 new_models: set[Model] = set()
#     214 for mr in document.roots:
# --> 215     new_models |= mr.references()
#     217 old_models = set(self._models.values())
#     219 to_detach = old_models - new_models
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\model\model.py:496, in Model.references(self)
#     492 def references(self) -> set[Model]:
#     493     ''' Returns all ``Models`` that this object has references to.
#     494
#     495     '''
# --> 496     return set(collect_models(self))
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\model\util.py:139, in collect_models(*input_values)
#     123 def collect_models(*input_values: Any) -> list[Model]:
#     124     ''' Collect a duplicate-free list of all other Bokeh models referred to by
#     125     this model, or by any of its references, etc.
#     126
#    (...)
#     137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\model\util.py:119, in collect_filtered_models(discard, *input_values)
#     117         ids.add(obj.id)
#     118         collected.append(obj)
# --> 119         visit_immediate_value_references(obj, queue_one)
#     121 return collected
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\model\util.py:185, in visit_immediate_value_references(value, visitor)
#     183 if isinstance(value, HasProps):
#     184     for attr in value.properties_with_refs():
# --> 185         child = getattr(value, attr)
#     186         visit_value_and_its_immediate_references(child, visitor)
#     187 else:
#
# File c:\Users\nayak\anaconda3\envs\ineuron_env\lib\site-packages\bokeh\core\property\descriptors.py:282, in PropertyDescriptor.__get__(self, obj, owner)
#     280     value = self._get(obj)
#     281     if value is Undefined:
# --> 282         raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283     return value
#     285 elif owner is not None:
#
# UnsetValueError: Circle(id='p1046', ...).radius doesn't have a value set

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from bokeh.plotting import figure ,output_file , show
from bokeh.sampledata.iris import flowers

output_file('line.html')

p = figure(title = "line graph")
p.xaxis.axis_label = "x axis"
p.yaxis.axis_label = "y axis"
p.line(flowers['petal_length'] , flowers['petal_width'])
show(p)

# %%
x = [2,3,4,5,6]
y = [3,4,5,6,7]
output_file("line.html")
p = figure(title = "line plot")
p.line(x,y)
show(p)

# %%
x = [2,3,4,5,6]
y = [3,4,5,6,7]
output_file("line.html")
p = figure(title = "line plot")
p.scatter(x,y,fill_color = 'red' , legend_label = 'red points',size = 20)
show(p)

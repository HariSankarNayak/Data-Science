# %%
import math

# %%
import zero
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import zero
#
# ModuleNotFoundError: No module named 'zero'

# %%
def sqrtMine():

# %%
from math import sqrt

math.sqrt(5)
# Out:
# 2.23606797749979

# %%
import pymongo # not installed

# %% [markdown]
# # Linear Regression

# %%
import math as ma

# %%
ma.sqrt(5)
# Out:
# 2.23606797749979

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def linear_regression (X,y,learning_rate,n_iteration):
    pass

# %%
import numpy as np

def linear_regression(X, y, learning_rate=0.01, n_iterations=100000):
    n_samples, n_features = X.shape
    weights = np.zeros(n_features)
    bias = 0
    for _ in range(n_iterations):
        # Predict the values
        y_predicted = np.dot(X, weights) + bias

        # Compute gradients
        dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y))
        db = (1 / n_samples) * np.sum(y_predicted - y)

        # Update parameters
        weights -= learning_rate * dw
        bias -= learning_rate * db

    return weights, bias

# %%
# Sample dataset
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])

# Train the model
weights, bias = linear_regression(X, y)

# Predict new values
X_test = np.array([[6], [7]])
predictions = np.dot(X_test, weights) + bias

print("Predictions:", predictions)
# Out:
# Predictions: [5.8 6.4]

# %%
from sklearn.linear_model import LinearRegression

# %%
# Sample dataset
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])

lr = LinearRegression()

# %%
lr.fit(X,y)
X_test = np.array([[6], [7]])
predictions = lr.predict(X_test)
predictions
# Out:
# array([5.8, 6.4])
